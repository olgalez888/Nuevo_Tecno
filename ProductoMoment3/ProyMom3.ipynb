# %%
import pandas as pd

# %%
info_vehiculos = pd.read_csv('/content/drive/MyDrive/BaseDatosFasecoldaNew.csv',sep=";",encoding = "ISO-8859-1")

# %%
info_vehiculos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16456 entries, 0 to 16455
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Novedad             16456 non-null  object
#  1   Marca               16456 non-null  object
#  2   Clase               16456 non-null  object
#  3   Codigo              16456 non-null  int64
#  4   Homologocodigo      16456 non-null  int64
#  5   Referencia1         16456 non-null  object
#  6   Referencia2         16456 non-null  object
#  7   Referencia3         16456 non-null  object
#  8   Peso                16456 non-null  int64
#  9   IdServicio          16456 non-null  int64
#  10  Servicio            16456 non-null  object
#  11  2024                16456 non-null  int64
#  12  Bcpp                16456 non-null  int64
#  13  Importado           16456 non-null  int64
#  14  Potencia            16456 non-null  int64
#  15  TipoCaja            15901 non-null  object
#  16  Cilindraje          16456 non-null  int64
#  17  Nacionalidad        16456 non-null  object
#  18  CapacidadPasajeros  16456 non-null  int64
#  19  CapacidadCarga      16456 non-null  int64
#  20  Puertas             16456 non-null  int64
#  21  AireAcondicionado   16456 non-null  int64
#  22  Ejes                16456 non-null  int64
#  23  Estado              16456 non-null  object
#  24  Combustible         15937 non-null  object
#  25  Transmision         15950 non-null  object
#  26  Um                  16456 non-null  int64
#  27  PesoCategoria       16456 non-null  int64
# dtypes: int64(16), object(12)
# memory usage: 3.5+ MB

# %%
info_vehiculos.head(10)
# Out:
#   Novedad           Marca             Clase  Codigo  Homologocodigo  \
# 0       M           ALEKO         AUTOMOVIL  101001          132001
# 1       A  AMERICAN MOTOR           CAMPERO  208003          236001
# 2       A  AMERICAN MOTOR           CAMPERO  208004          236002
# 3       A  AMERICAN MOTOR  CAMIONETA PASAJ.  206001          237001
# 4       N           BAJAJ         AUTOMOVIL  301001          332001
# 5       A           BAJAJ         MOTOCARRO  319001          351001
# 6       A           BAJAJ         MOTOCARRO  319003          351003
# 7       A           BAJAJ         MOTOCARRO  319004          351004
# 8       A           BAJAJ         MOTOCARRO  319005          351005
# 9       A           BAJAJ         MOTOCARRO  319006          351006
#
#    Referencia1   Referencia2        Referencia3  Peso  IdServicio  ...  \
# 0         2141           1.6     MT 1600CC TAXI  1380           2  ...
# 1     WRANGLER           4.2      MT 4200CC CAB  1100           1  ...
# 2     WRANGLER           4.2  MT 2500CC CARPADO  1100           1  ...
# 3        EAGLE        SUMMIT    AT 2400CC LX 4P     0           1  ...
# 4         QUTE           200           MT 200CC   399           1  ...
# 5  PICK-UP VAN           150           MT 150CC   283           1  ...
# 6  PICK-UP VAN           175           MT 175CC   305           1  ...
# 7  PICK-UP VAN           400       MT 400CC DSL   353           1  ...
# 8    CAMELLITO  FURGON [ASL]           MT 175CC   350           1  ...
# 9    CAMELLITO        FURGON           MT 175CC   350           1  ...
#
#   CapacidadPasajeros  CapacidadCarga  Puertas  AireAcondicionado  Ejes  \
# 0                  5               0        5                  0     2
# 1                  5               0        3                  1     2
# 2                  5               0        3                  1     2
# 3                  5               0        5                  0     2
# 4                  4               0        4                  0     2
# 5                  2               0        2                  0     2
# 6                  3               0        0                  0     2
# 7                  3               0        0                  0     2
# 8                  3             325        0                  0     2
# 9                  3             325        0                  0     2
#
#    Estado  Combustible Transmision  Um  PesoCategoria
# 0  ACTIVO          GSL         4X2   0              1
# 1  ACTIVO          GSL         4X4   0              1
# 2  ACTIVO          GSL         4X4   0              1
# 3  ACTIVO          GSL         4X2   0              1
# 4  ACTIVO          GSL         4X2   0              1
# 5  ACTIVO          GSL         3X1   0              1
# 6  ACTIVO          GSL         3X1   0              1
# 7  ACTIVO          GSL         3X1   0              1
# 8  ACTIVO          GSL         3X1   0              1
# 9  ACTIVO          GSL         3X1   0              1
#
# [10 rows x 28 columns]

# %%
info_vehiculos.tail(10)
# Out:
#       Novedad                        Marca                    Clase    Codigo  \
# 16446       N                        JINMA                AUTOMOVIL  45701001
# 16447       N                 IONIC MOTORS              MOTOCICLETA  45817001
# 16448       N                 IONIC MOTORS              MOTOCICLETA  45817002
# 16449       N                       DMECOL                 REMOLQUE  45925001
# 16450       N            INDUSTRIAS PATIÑO                 REMOLQUE  46025001
# 16451       N            INDUSTRIAS BUFALO                 REMOLQUE  46125001
# 16452       N                      MOTORED                MOTOCARRO  46319001
# 16453       N                      MOTORED                MOTOCARRO  46319002
# 16454       M                   ZHONG TONG  BUS / BUSETA / MICROBUS  46403001
# 16455       N  INDUSTRIA METALMECANICA ECT                 REMOLQUE  46525001
#
#        Homologocodigo Referencia1          Referencia2   Referencia3  Peso  \
# 16446        45732001          J2            ELECTRICO  AT 3000W R12   560
# 16447        45857001         IOZ            ELECTRICO     AT 5000W      0
# 16448        45857002         IOT            ELECTRICO      AT 3000W     0
# 16449        45987001       VOLCO     VOLTEO POSTERIOR        3 EJES     0
# 16450        46087001       VOLCO     VOLTEO POSTERIOR        3 EJES     0
# 16451        46186001      TANQUE                [STD]        3 EJES  4000
# 16452        46351001        EMTK                2.2WP     AT 2200W    660
# 16453        46351002        EMTK                3.0WL     AT 3000W   1100
# 16454        46471001         LCK  6606EVG [10-20 PSJ]   AT 89KW ABS     0
# 16455        46582001  PLATAFORMA              ESTACAS        3 EJES  6600
#
#        IdServicio  ... CapacidadPasajeros  CapacidadCarga  Puertas  \
# 16446           1  ...                  3               0        2
# 16447           1  ...                  2               0        0
# 16448           1  ...                  1               0        0
# 16449           2  ...                  0               0        0
# 16450           2  ...                  0               0        0
# 16451           2  ...                  0           25000        0
# 16452           1  ...                  1               0        0
# 16453           1  ...                  1               0        0
# 16454           2  ...                 20               0        1
# 16455           2  ...                  0           35000        0
#
#        AireAcondicionado  Ejes  Estado  Combustible Transmision  Um  \
# 16446                  1     2  ACTIVO          ELT         4X2   0
# 16447                  0     2  ACTIVO          ELT         2X1   0
# 16448                  0     2  ACTIVO          ELT         2X1   0
# 16449                  0     3  ACTIVO          NaN         NaN   0
# 16450                  0     3  ACTIVO          NaN         NaN   1
# 16451                  0     3  ACTIVO          NaN         NaN   0
# 16452                  0     2  ACTIVO          ELT         2X1   0
# 16453                  0     2  ACTIVO          ELT         2X1   0
# 16454                  1     2  ACTIVO          ELT         4X2   1
# 16455                  0     3  ACTIVO          NaN         NaN   0
#
#        PesoCategoria
# 16446              1
# 16447              1
# 16448              1
# 16449              1
# 16450              1
# 16451              0
# 16452              1
# 16453              1
# 16454              1
# 16455              0
#
# [10 rows x 28 columns]

# %%
list(info_vehiculos['Clase'].drop_duplicates().tail(10))
# Out:
# ['REMOLCADOR',
#  'CARROTANQUE',
#  'CHASIS',
#  'CAMION',
#  'FURGON',
#  'VOLQUETA',
#  'CUATRIMOTO',
#  'FURGONETA',
#  'ISOCARRO',
#  'REMOLQUE']

# %%
list(info_vehiculos['Nacionalidad'].drop_duplicates())
# Out:
# ['RUS',
#  'USA',
#  'IND',
#  'COL',
#  'TWN',
#  'JAP',
#  'MEX',
#  'RUM',
#  'KOR',
#  'ALE',
#  'HNG',
#  'BRA',
#  'CHI',
#  'ITA',
#  'SUE',
#  'ECU',
#  'VEN',
#  'CAN',
#  'TAI',
#  'CHL',
#  'FRA',
#  'ARG',
#  'ESP',
#  'CZE',
#  'ENG',
#  'IDN',
#  'PAN',
#  'SVK',
#  'UKR',
#  'NED',
#  'AUS',
#  'VNM']

# %%
list(info_vehiculos['Marca'].drop_duplicates().tail(10))
# Out:
# ['INDUSTRIAS PATAQUIVA IMPA',
#  'ATUL',
#  'JINMA',
#  'IONIC MOTORS',
#  'DMECOL',
#  'INDUSTRIAS PATIÑO',
#  'INDUSTRIAS BUFALO',
#  'MOTORED',
#  'ZHONG TONG',
#  'INDUSTRIA METALMECANICA ECT']

# %%
clase =['AUTOMOVIL',
'CAMIONETA PASAJ.',
'MOTOCICLETA',
'BUS / BUSETA / MICROBUS',
'REMOLCADOR',
'CARROTANQUE',
'CAMION',
'VOLQUETA',
'CUATRIMOTO'
 ]

# %%
clase
# Out:
# ['AUTOMOVIL',
#  'CAMIONETA PASAJ.',
#  'MOTOCICLETA',
#  'BUS / BUSETA / MICROBUS',
#  'REMOLCADOR',
#  'CARROTANQUE',
#  'CAMION',
#  'VOLQUETA',
#  'CUATRIMOTO']

# %%
info_clase=info_vehiculos['Clase'].isin(clase)

# %%
datos_clase=info_vehiculos[info_clase]

# %%
datos_clase
# Out:
#       Novedad           Marca                    Clase    Codigo  \
# 0           M           ALEKO                AUTOMOVIL    101001
# 3           A  AMERICAN MOTOR         CAMIONETA PASAJ.    206001
# 4           N           BAJAJ                AUTOMOVIL    301001
# 33          M           BAJAJ              MOTOCICLETA    317067
# 34          A           BAJAJ              MOTOCICLETA    317035
# ...       ...             ...                      ...       ...
# 16440       N         TALARIA              MOTOCICLETA  45217001
# 16446       N           JINMA                AUTOMOVIL  45701001
# 16447       N    IONIC MOTORS              MOTOCICLETA  45817001
# 16448       N    IONIC MOTORS              MOTOCICLETA  45817002
# 16454       M      ZHONG TONG  BUS / BUSETA / MICROBUS  46403001
#
#        Homologocodigo Referencia1          Referencia2      Referencia3  Peso  \
# 0              132001        2141                  1.6   MT 1600CC TAXI  1380
# 3              237001       EAGLE               SUMMIT  AT 2400CC LX 4P     0
# 4              332001        QUTE                  200         MT 200CC   399
# 33             353001      PULSAR               200 RS         MT 200CC   165
# 34             354001     VICTORY                FURAX         MT 150CC    80
# ...               ...         ...                  ...              ...   ...
# 16440        45254001       STING                  L1E         AT 3.0KW    58
# 16446        45732001          J2            ELECTRICO     AT 3000W R12   560
# 16447        45857001         IOZ            ELECTRICO        AT 5000W      0
# 16448        45857002         IOT            ELECTRICO         AT 3000W     0
# 16454        46471001         LCK  6606EVG [10-20 PSJ]      AT 89KW ABS     0
#
#        IdServicio  ... CapacidadPasajeros  CapacidadCarga  Puertas  \
# 0               2  ...                  5               0        5
# 3               1  ...                  5               0        5
# 4               1  ...                  4               0        4
# 33              1  ...                  2               0        0
# 34              1  ...                  2               0        0
# ...           ...  ...                ...             ...      ...
# 16440           1  ...                  1               0        0
# 16446           1  ...                  3               0        2
# 16447           1  ...                  2               0        0
# 16448           1  ...                  1               0        0
# 16454           2  ...                 20               0        1
#
#        AireAcondicionado  Ejes  Estado  Combustible Transmision  Um  \
# 0                      0     2  ACTIVO          GSL         4X2   0
# 3                      0     2  ACTIVO          GSL         4X2   0
# 4                      0     2  ACTIVO          GSL         4X2   0
# 33                     0     2  ACTIVO          GSL         2X1   1
# 34                     0     2  ACTIVO          GSL         2X1   0
# ...                  ...   ...     ...          ...         ...  ..
# 16440                  0     2  ACTIVO          ELT         2X1   0
# 16446                  1     2  ACTIVO          ELT         4X2   0
# 16447                  0     2  ACTIVO          ELT         2X1   0
# 16448                  0     2  ACTIVO          ELT         2X1   0
# 16454                  1     2  ACTIVO          ELT         4X2   1
#
#        PesoCategoria
# 0                  1
# 3                  1
# 4                  1
# 33                 1
# 34                 1
# ...              ...
# 16440              1
# 16446              1
# 16447              1
# 16448              1
# 16454              1
#
# [11082 rows x 28 columns]

# %%
datos_clase.shape
# Out:
# (11082, 28)

# %%
datos_clase.index=range(datos_clase.shape[0])

# %%
datos_clase.head(30)
# Out:
#    Novedad           Marca             Clase  Codigo  Homologocodigo  \
# 0        M           ALEKO         AUTOMOVIL  101001          132001
# 1        A  AMERICAN MOTOR  CAMIONETA PASAJ.  206001          237001
# 2        N           BAJAJ         AUTOMOVIL  301001          332001
# 3        M           BAJAJ       MOTOCICLETA  317067          353001
# 4        A           BAJAJ       MOTOCICLETA  317035          354001
# 5        A           BAJAJ       MOTOCICLETA  317003          355001
# 6        A           BAJAJ       MOTOCICLETA  317009          355002
# 7        A           BAJAJ       MOTOCICLETA  317028          355003
# 8        M           BAJAJ       MOTOCICLETA  317006          356001
# 9        A           BAJAJ       MOTOCICLETA  317007          356002
# 10       M           BAJAJ       MOTOCICLETA  317010          356003
# 11       M           BAJAJ       MOTOCICLETA  317016          356004
# 12       M           BAJAJ       MOTOCICLETA  317017          356005
# 13       M           BAJAJ       MOTOCICLETA  317019          356006
# 14       M           BAJAJ       MOTOCICLETA  317022          356007
# 15       A           BAJAJ       MOTOCICLETA  317004          357001
# 16       A           BAJAJ       MOTOCICLETA  317008          357002
# 17       M           BAJAJ       MOTOCICLETA  317015          357003
# 18       M           BAJAJ       MOTOCICLETA  317025          357004
# 19       M           BAJAJ       MOTOCICLETA  317029          357005
# 20       M           BAJAJ       MOTOCICLETA  317030          357006
# 21       M           BAJAJ       MOTOCICLETA  317037          357007
# 22       M           BAJAJ       MOTOCICLETA  317038          357008
# 23       M           BAJAJ       MOTOCICLETA  317039          357009
# 24       M           BAJAJ       MOTOCICLETA  317041          357010
# 25       M           BAJAJ       MOTOCICLETA  317042          357011
# 26       M           BAJAJ       MOTOCICLETA  317043          357012
# 27       M           BAJAJ       MOTOCICLETA  317044          357013
# 28       M           BAJAJ       MOTOCICLETA  317045          357014
# 29       M           BAJAJ       MOTOCICLETA  317046          357015
#
#      Referencia1     Referencia2      Referencia3  Peso  IdServicio  ...  \
# 0           2141             1.6   MT 1600CC TAXI  1380           2  ...
# 1          EAGLE          SUMMIT  AT 2400CC LX 4P     0           1  ...
# 2           QUTE             200         MT 200CC   399           1  ...
# 3         PULSAR          200 RS         MT 200CC   165           1  ...
# 4        VICTORY           FURAX         MT 150CC    80           1  ...
# 5           SUMA              80       MT 80CC 2T    75           1  ...
# 6          SUNNY              80          MT 80CC   105           1  ...
# 7            MAX             100         MT 100CC    79           1  ...
# 8     PLUS POWER             150         AT 150CC    95           1  ...
# 9            ZIP              80          AT 80CC    77           1  ...
# 10  PLUS CLASSIC             150         MT 150CC   106           1  ...
# 11        LEGEND             150         MT 150CC   108           1  ...
# 12         BRAVO             145         MT 145CC   103           1  ...
# 13        SPIRIT              60          AT 60CC    76           1  ...
# 14           NXT             150         MT 150CC    80           1  ...
# 15           KTZ             100         MT 100CC    78           1  ...
# 16            KB             125         MT 125CC    93           1  ...
# 17         BOXER           CT100         MT 100CC   113           1  ...
# 18        PULSAR             180         MT 180CC   143           1  ...
# 19        AVANTI              90          MT 90CC    98           1  ...
# 20    CALIBER II             115         MT 115CC   118           1  ...
# 21  DISCOVER [1]             125         MT 125CC   125           1  ...
# 22     PULSAR II             180         MT 180CC   143           1  ...
# 23       PLATINO             100         MT 100CC   113           1  ...
# 24  DISCOVER [2]         SUPREME         MT 135CC   133           1  ...
# 25  DISCOVER [2]           SPORT         MT 135CC   133           1  ...
# 26        PULSAR             200         MT 200CC   145           1  ...
# 27           XCD             125         MT 125CC   112           1  ...
# 28        PULSAR              UG         MT 180CC   150           1  ...
# 29         BOXER  BM CLASSIC [1]         MT 100CC   109           1  ...
#
#    CapacidadPasajeros  CapacidadCarga  Puertas  AireAcondicionado  Ejes  \
# 0                   5               0        5                  0     2
# 1                   5               0        5                  0     2
# 2                   4               0        4                  0     2
# 3                   2               0        0                  0     2
# 4                   2               0        0                  0     2
# 5                   2               0        0                  0     2
# 6                   2               0        0                  0     2
# 7                   2               0        0                  0     2
# 8                   2               0        0                  0     2
# 9                   2               0        0                  0     2
# 10                  2               0        0                  0     2
# 11                  2               0        0                  0     2
# 12                  2               0        0                  0     2
# 13                  2               0        0                  0     2
# 14                  2               0        0                  0     2
# 15                  2               0        0                  0     2
# 16                  2               0        0                  0     2
# 17                  2               0        0                  0     2
# 18                  2               0        0                  0     2
# 19                  2               0        0                  0     2
# 20                  2               0        0                  0     2
# 21                  2               0        0                  0     2
# 22                  2               0        0                  0     2
# 23                  2               0        0                  0     2
# 24                  2               0        0                  0     2
# 25                  2               0        0                  0     2
# 26                  2               0        0                  0     2
# 27                  2               0        0                  0     2
# 28                  2               0        0                  0     2
# 29                  2               0        0                  0     2
#
#     Estado  Combustible Transmision  Um  PesoCategoria
# 0   ACTIVO          GSL         4X2   0              1
# 1   ACTIVO          GSL         4X2   0              1
# 2   ACTIVO          GSL         4X2   0              1
# 3   ACTIVO          GSL         2X1   1              1
# 4   ACTIVO          GSL         2X1   0              1
# 5   ACTIVO          GSL         2X1   0              1
# 6   ACTIVO          GSL         2X1   0              1
# 7   ACTIVO          GSL         2X1   0              1
# 8   ACTIVO          GSL         2X1   0              1
# 9   ACTIVO          GSL         2X1   0              1
# 10  ACTIVO          GSL         2X1   0              1
# 11  ACTIVO          GSL         2X1   0              1
# 12  ACTIVO          GSL         2X1   0              1
# 13  ACTIVO          GSL         2X1   0              1
# 14  ACTIVO          GSL         2X1   0              1
# 15  ACTIVO          GSL         2X1   0              1
# 16  ACTIVO          GSL         2X1   0              1
# 17  ACTIVO          GSL         2X1   0              1
# 18  ACTIVO          GSL         2X1   0              1
# 19  ACTIVO          GSL         2X1   0              1
# 20  ACTIVO          GSL         2X1   0              1
# 21  ACTIVO          GSL         2X1   0              1
# 22  ACTIVO          GSL         2X1   0              1
# 23  ACTIVO          GSL         2X1   0              1
# 24  ACTIVO          GSL         2X1   0              1
# 25  ACTIVO          GSL         2X1   0              1
# 26  ACTIVO          GSL         2X1   0              1
# 27  ACTIVO          GSL         2X1   0              1
# 28  ACTIVO          GSL         2X1   0              1
# 29  ACTIVO          GSL         2X1   0              1
#
# [30 rows x 28 columns]

# %%
sel_automovil=datos_clase['Clase']=="AUTOMOVIL"
cant_automovil=datos_clase[sel_automovil].shape[0]
cant_automovil
# Out:
# 4688

# %%
sel_otros_automovil=datos_clase['Clase']=="AUTOMOVIL"
cant_otras=datos_clase[~sel_otros_automovil].shape[0]
cant_otras
# Out:
# 6394

# %%
cant_automovil_automatico_particular=((datos_clase['Clase']=="AUTOMOVIL") | (datos_clase['Clase']=="CAMION")) & (datos_clase['Servicio']=="Publico") & (datos_clase['TipoCaja']=="AT")
cant_automovil_automatico=datos_clase[cant_automovil_automatico_particular].shape[0]
cant_automovil_automatico
# Out:
# 20

# %%
sel_cilindraje=(datos_clase['Cilindraje']>=1800) & (datos_clase['Cilindraje']<=2000)
cant_cilindraje=datos_clase[sel_cilindraje].shape[0]
cant_cilindraje
# Out:
# 1468

# %%
sel_cilindraje_puertas=(datos_clase['Cilindraje']>=1800) & (datos_clase['Cilindraje']<=2000) & (datos_clase['Puertas']==2)
cant_cilindraje_puertas=datos_clase[sel_cilindraje_puertas].shape[0]
cant_cilindraje_puertas
# Out:
# 134

# %%
print("Se encontraron los sgtes resultados:")
print(f"La cantidad de automoviles es de: {cant_automovil}")
print(f"La cantidad de otras clases de vehiculos es de: {cant_otras}")
print(f"La cantidad de automoviles o camiones publicos automáticos es de: {cant_automovil_automatico}")
print(f"La cantidad de vehiculos con cilidraje entre 1800 y 2000 es de: {cant_cilindraje}")
print(f"La cantidad de vehiculos cilidraje entre 1800 y 2000 y solo 2 puertas: {cant_cilindraje_puertas}")
# Out:
# Se encontraron los sgtes resultados:
# La cantidad de automoviles es de: 4688
# La cantidad de otras clases de vehiculos es de: 6394
# La cantidad de automoviles o camiones publicos automáticos es de: 20
# La cantidad de vehiculos con cilidraje entre 1800 y 2000 es de: 1468
# La cantidad de vehiculos cilidraje entre 1800 y 2000 y solo 2 puertas: 134

# %%
datos_clase.isnull()
# Out:
#        Novedad  Marca  Clase  Codigo  Homologocodigo  Referencia1  \
# 0        False  False  False   False           False        False
# 1        False  False  False   False           False        False
# 2        False  False  False   False           False        False
# 3        False  False  False   False           False        False
# 4        False  False  False   False           False        False
# ...        ...    ...    ...     ...             ...          ...
# 11077    False  False  False   False           False        False
# 11078    False  False  False   False           False        False
# 11079    False  False  False   False           False        False
# 11080    False  False  False   False           False        False
# 11081    False  False  False   False           False        False
#
#        Referencia2  Referencia3   Peso  IdServicio  ...  CapacidadPasajeros  \
# 0            False        False  False       False  ...               False
# 1            False        False  False       False  ...               False
# 2            False        False  False       False  ...               False
# 3            False        False  False       False  ...               False
# 4            False        False  False       False  ...               False
# ...            ...          ...    ...         ...  ...                 ...
# 11077        False        False  False       False  ...               False
# 11078        False        False  False       False  ...               False
# 11079        False        False  False       False  ...               False
# 11080        False        False  False       False  ...               False
# 11081        False        False  False       False  ...               False
#
#        CapacidadCarga  Puertas  AireAcondicionado   Ejes  Estado  Combustible  \
# 0               False    False              False  False   False        False
# 1               False    False              False  False   False        False
# 2               False    False              False  False   False        False
# 3               False    False              False  False   False        False
# 4               False    False              False  False   False        False
# ...               ...      ...                ...    ...     ...          ...
# 11077           False    False              False  False   False        False
# 11078           False    False              False  False   False        False
# 11079           False    False              False  False   False        False
# 11080           False    False              False  False   False        False
# 11081           False    False              False  False   False        False
#
#        Transmision     Um  PesoCategoria
# 0            False  False          False
# 1            False  False          False
# 2            False  False          False
# 3            False  False          False
# 4            False  False          False
# ...            ...    ...            ...
# 11077        False  False          False
# 11078        False  False          False
# 11079        False  False          False
# 11080        False  False          False
# 11081        False  False          False
#
# [11082 rows x 28 columns]

# %%
datos_clase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11082 entries, 0 to 11081
# Data columns (total 28 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Novedad             11082 non-null  object
#  1   Marca               11082 non-null  object
#  2   Clase               11082 non-null  object
#  3   Codigo              11082 non-null  int64
#  4   Homologocodigo      11082 non-null  int64
#  5   Referencia1         11082 non-null  object
#  6   Referencia2         11082 non-null  object
#  7   Referencia3         11082 non-null  object
#  8   Peso                11082 non-null  int64
#  9   IdServicio          11082 non-null  int64
#  10  Servicio            11082 non-null  object
#  11  2024                11082 non-null  int64
#  12  Bcpp                11082 non-null  int64
#  13  Importado           11082 non-null  int64
#  14  Potencia            11082 non-null  int64
#  15  TipoCaja            11037 non-null  object
#  16  Cilindraje          11082 non-null  int64
#  17  Nacionalidad        11082 non-null  object
#  18  CapacidadPasajeros  11082 non-null  int64
#  19  CapacidadCarga      11082 non-null  int64
#  20  Puertas             11082 non-null  int64
#  21  AireAcondicionado   11082 non-null  int64
#  22  Ejes                11082 non-null  int64
#  23  Estado              11082 non-null  object
#  24  Combustible         11073 non-null  object
#  25  Transmision         11075 non-null  object
#  26  Um                  11082 non-null  int64
#  27  PesoCategoria       11082 non-null  int64
# dtypes: int64(16), object(12)
# memory usage: 2.4+ MB

# %%
datos_clase.to_csv('ProyMom3.csv',sep=";",encoding = "ISO-8859-1")
