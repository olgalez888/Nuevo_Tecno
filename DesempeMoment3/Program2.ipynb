# %% [markdown]
# Analisis de alquileres para nuevas tecnologias

# %%
import pandas as pd

# %%
info_alquiler = pd.read_csv('/content/drive/MyDrive/ProgAlquiler.csv',sep=";")

# %% [markdown]
# # Nueva sección

# %%
info_alquiler.shape
# Out:
# (22941, 10)

# %%
info_alquiler.info
# Out:
# <bound method DataFrame.info of        Unnamed: 0          Tipo    Distrito  Cuartos  Vacantes  Suites  Area  \
# 0               0    Habitación   San Borja        1         0       0    40
# 1               1          Casa  Lurigancho        2         0       1   100
# 2               2  Departamento  Pachacámac        1         0       0    15
# 3               3  Departamento         Ate        1         0       0    48
# 4               4  Departamento    Barranco        3         1       0    70
# ...           ...           ...         ...      ...       ...     ...   ...
# 22936       22936       Cochera  Pachacámac        0         0       0   755
# 22937       22937    Habitación  Pachacámac        0         0       0    27
# 22938       22938  Departamento       Lince        3         1       2    78
# 22939       22939  Departamento       Rímac        2         1       0    48
# 22940       22940  Departamento       Rímac        2         0       0    70
#
# ...

# %%
info_alquiler.describe()
# Out:
#          Unnamed: 0       Cuartos      Vacantes        Suites          Area  \
# count  22941.000000  22941.000000  22941.000000  22941.000000  22941.000000
# mean   11470.000000      2.482368      1.286343      0.942069    135.000479
# std     6622.640599      1.122569     12.992997      1.142429    144.615854
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%     5735.000000      2.000000      0.000000      0.000000     63.000000
# 50%    11470.000000      2.000000      1.000000      1.000000     90.000000
# 75%    17205.000000      3.000000      2.000000      1.000000    150.000000
# max    22940.000000     32.000000   1960.000000     23.000000   3000.000000
#
#               Valor  Mantenimiento       Impuesto
# count  2.293200e+04   2.117000e+04   16155.000000
# mean   4.997061e+03   1.654347e+03     792.797833
# std    3.220310e+04   4.519814e+04    4437.303655
# min    9.000000e+01   1.000000e+00       1.000000
# ...

# %% [markdown]
# head me muestra por defecto los primeros 5, imprime los primero datos del dataframe,si le pongo 10 muestra 10

# %%
info_alquiler.head(10)
# Out:
#    Unnamed: 0                Tipo     Distrito  Cuartos  Vacantes  Suites  \
# 0           0          Habitación    San Borja        1         0       0
# 1           1                Casa   Lurigancho        2         0       1
# 2           2        Departamento   Pachacámac        1         0       0
# 3           3        Departamento          Ate        1         0       0
# 4           4        Departamento     Barranco        3         1       0
# 5           5        Departamento        Comas        2         0       0
# 6           6  Casa en condominio          Ate        5         4       5
# 7           7  Casa en condominio  El Agustino        2         2       0
# 8           8        Departamento   Pachacámac        1         0       0
# 9           9        Departamento      Mi Perú        2         1       0
#
#    Area    Valor  Mantenimiento  Impuesto
# 0    40   1700.0          500.0      60.0
# 1   100   7000.0            NaN       NaN
# ...

# %%
info_alquiler.tail(7)
# Out:
#        Unnamed: 0                Tipo     Distrito  Cuartos  Vacantes  Suites  \
# 22934       22934  Casa en condominio          Ate        5         3       4
# 22935       22935        Departamento  Santa Anita        2         0       0
# 22936       22936             Cochera   Pachacámac        0         0       0
# 22937       22937          Habitación   Pachacámac        0         0       0
# 22938       22938        Departamento        Lince        3         1       2
# 22939       22939        Departamento        Rímac        2         1       0
# 22940       22940        Departamento        Rímac        2         0       0
#
#        Area    Valor  Mantenimiento  Impuesto
# 22934   450  15000.0         1711.0    2332.0
# 22935    70    900.0          490.0      48.0
# 22936   755  14000.0            NaN       NaN
# 22937    27    800.0          350.0      25.0
# 22938    78   1800.0          800.0      40.0
# 22939    48   1400.0          509.0      37.0
# ...

# %%
list(info_alquiler['Tipo'].drop_duplicates())
# Out:
# ['Habitación',
#  'Casa',
#  'Departamento',
#  'Casa en condominio',
#  'Flat',
#  'Cochera',
#  'Loft',
#  'Chalet']

# %%
list(info_alquiler['Distrito'].drop_duplicates())
# Out:
# ['San Borja',
#  'Lurigancho',
#  'Pachacámac',
#  'Ate',
#  'Barranco',
#  'Comas',
#  'El Agustino',
#  'Mi Perú',
#  'Chorrillos',
#  'San Luis',
#  'Callao',
#  'San Miguel',
#  'Santa Rosa',
#  'Rímac',
#  'Lince',
#  'Jesús María',
#  'Miraflores',
#  'Breña',
#  'Ancón',
#  'Santa Anita',
#  'Villa María del Triunfo',
#  'Punta Hermosa',
#  'La Perla',
#  'San Juan de Lurigancho',
#  'Chaclacayo',
#  'Villa El Salvador',
#  'Pueblo Libre',
#  'Lurín',
#  'La Punta',
#  'Ventanilla',
#  'Magdalena del Mar',
#  'Santa María del Mar',
#  'Puente Piedra',
#  'Bellavista',
#  'Punta Negra',
#  'San Juan de Miraflores',
#  'San Isidro',
#  'San Bartolo',
#  'Santiago de Surco',
#  'Carmen de La Legua',
#  'Los Olivos',
#  'Pucusana',
#  'San Martín de Porres',
#  'La Molina',
#  'Cieneguilla',
#  'Lima',
#  'Surquillo',
#  'La Victoria',
#  'Independencia',
#  'Carabayllo']

# %%
viviendas =['Habitación',
 'Casa',
 'Departamento',
 'Casa en condominio',
 'Flat',
 'casa de villa',
 'Cochera',
 'Loft',
 'Chalet',
 ]

# %% [markdown]
# vamos a crear un nuevo dataframe, sacar un subconjunto que pueda manipular y convertirlo a una nueva base de datos.llamada info_viviendas

# %%
filtro_viviendas=info_alquiler['Tipo'].isin(viviendas)

# %%
filtro_viviendas
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#          ...
# 22936    True
# 22937    True
# 22938    True
# 22939    True
# 22940    True
# Name: Tipo, Length: 22941, dtype: bool

# %%
datos_viviendas=info_alquiler[filtro_viviendas]

# %% [markdown]
# trae la info alquiler pero filtrada con info viviendas solo los true, linea 22

# %%
datos_viviendas
# Out:
#        Unnamed: 0          Tipo    Distrito  Cuartos  Vacantes  Suites  Area  \
# 0               0    Habitación   San Borja        1         0       0    40
# 1               1          Casa  Lurigancho        2         0       1   100
# 2               2  Departamento  Pachacámac        1         0       0    15
# 3               3  Departamento         Ate        1         0       0    48
# 4               4  Departamento    Barranco        3         1       0    70
# ...           ...           ...         ...      ...       ...     ...   ...
# 22936       22936       Cochera  Pachacámac        0         0       0   755
# 22937       22937    Habitación  Pachacámac        0         0       0    27
# 22938       22938  Departamento       Lince        3         1       2    78
# 22939       22939  Departamento       Rímac        2         1       0    48
# 22940       22940  Departamento       Rímac        2         0       0    70
#
#          Valor  Mantenimiento  Impuesto
# ...

# %%
datos_viviendas.shape
# Out:
# (22941, 10)

# %% [markdown]
# vamos a resetiar los indices que me quedaron mal

# %%
datos_viviendas.index=range(datos_viviendas.shape[0])

# %%
datos_viviendas.head(30)
# Out:
#     Unnamed: 0                Tipo     Distrito  Cuartos  Vacantes  Suites  \
# 0            0          Habitación    San Borja        1         0       0
# 1            1                Casa   Lurigancho        2         0       1
# 2            2        Departamento   Pachacámac        1         0       0
# 3            3        Departamento          Ate        1         0       0
# 4            4        Departamento     Barranco        3         1       0
# 5            5        Departamento        Comas        2         0       0
# 6            6  Casa en condominio          Ate        5         4       5
# 7            7  Casa en condominio  El Agustino        2         2       0
# 8            8        Departamento   Pachacámac        1         0       0
# 9            9        Departamento      Mi Perú        2         1       0
# 10          10        Departamento    San Borja        3         1       1
# ...

# %%
datos_viviendas.to_csv('ProgAlquiler.csv',sep=';')
